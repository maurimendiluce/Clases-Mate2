# %% [markdown]
# # Matemática II Biología - 2do. cuatrimestre 2022
# ${\textbf{Entrega  N° 1 (Práctica 1)}}$
#
# ---------------------------------
#
# Subir el archivo en formato $\textbf{Entrega1-Nombre-Apellido.ipynb}$
#
# Para este trabajo vamos a utilizar los paquetes $\texttt{numpy}$, $\texttt{plot}$ de $\texttt{matplotlib}$ e $\texttt{interpolate}$ de $\texttt{scipy}$.

# %%
#importar los paquetes necesarios

# %% [markdown]
# **Ejercicio 1:**
#
# Consideremos la función $f(x)=e^{-20x^2}$.
#
# 1.   Definir una función que calcule los valores de $f$ en cada $x$
# 2.   Usando polyfit, realizar las interpolaciones en el intervalo $[-1,1]$ para $15$ puntos equiespaciados y para $15$ nodos de Chebychev.
# 3.  Calcular un spline cubico para estos puntos.
# 4.  Graficar la función y las interpolaciones en el intervalo $[-1.1 , 1.1]$ en un mismo gráfico.

# %%
##Definir función

# %%
##Interpolación con puntos equiespaciados

# %%
##Interpolación con nodos de Chebychev

# %%
##Interpolación con spline cúbico

# %%
##Hacer gráfico de f(x) y las interpolaciones

# %% [markdown]
# **Ejercicio 3:**
#
# Considere $a \in \mathbb{R}$ un número real y la función $f(x)=(1+x)^a$.
# 1.   Defina una función de parámetros $a$ y $n$ que devuelva el $n-$ésimo coeficiente del polinomio de Taylor de $f(x)$ en $x_0 = 0$.
# 2.   Estime el valor $\frac{1}{\sqrt[3]{1.1}}$ de la siguiente manera: utilizando $\texttt{poly1d}$, construya el polinomio de grado 4 de Taylor en $x_0=0$ de $f$ para el valor de $a$ adecuado y estimar el error cometido (recordar que para estimar el error usamos $|f(x)-P_n(x)|$).

# %%
##Definir función de coeficiente de Taylor

# %%
##Construir el polinomio de Taylor de grado 4

# %%
##Devuelvor el valor a estimar usando el polinomio

# %%
##Estimación del error
